# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import gzip
import pandas as pd
from collections import Counter

# Read the content of the error file.
def readErrorContent(path):
  data = pd.read_csv(path, compression='gzip') 

  # Replacing 403 errors with the common error content
  return data["error"].str.replace(r'(403 Client Error: Forbidden for url:.*$)', '403 Client Error: Forbidden for url')

# %%
import os
import re
import glob
from collections import Counter
from pathlib import Path

error_list = []
error_count = 1
error_count_in_news = dict()
news_base_path = "/content/drive/MyDrive/Twitter/live_news/"
news_agents = os.listdir(news_base_path)

#Loop through the folders to find the error content from error file
for agent in news_agents:
  path = Path(news_base_path+agent+"/")
  error_files = path.rglob('error_url.csv.gz')
  #print(error_files)
  error_list = []
  for file in error_files:    
    error_list.append(readErrorContent(file))
  error_count_in_news[agent] = Counter(error_list[0])

for key, value in error_count_in_news.items():
  print("------------")
  print('\033[1m' +key + '\033[0m')
  print("------------")
  for item in value.most_common():
    print(item[0] + " : " + (str)(item[1]))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   # Remove the CWD from sys.path while we load stuff.
# ------------
# thesun
# ------------
# module 'the_sun' has no attribute 'extract_the_sun_structure' : 62
# HTTPConnectionPool(host='kenzo.kim', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f088a0b9050>: Failed to establish a new connection: [Errno -2] Name or service not known')) : 1
# ------------
# conversationuk
# ------------
# too many values to unpack (expected 3) : 4
# not all arguments converted during string formatting : 3
# not enough values to unpack (expected 3, got 1) : 1
# ------------
# reuters
# ------------
# not all arguments converted during string formatting : 293
# 'NoneType' object has no attribute 'h1' : 20
# ------------
# dailystar
# ------------
# 403 Client Error: Forbidden for url : 359
# module 'daily_star' has no attribute 'extract_num_daily_star_paras' : 66
# ------------
# skynews
# ------------
# not all arguments converted during string formatting : 96
# 'NoneType' object has no attribute 'text' : 17
# 'NoneType' object has no attribute 'find_all' : 3
# ------------
# daily_express
# ------------
# too many values to unpack (expected 3) : 280
# not enough values to unpack (expected 3, got 2) : 7
# 'NoneType' object has no attribute 'text' : 2
# not all arguments converted during string formatting : 2
# 'NoneType' object has no attribute 'find_all' : 1
# ------------
# guardian
# ------------
# Not extracting title from news source guardian : 172
# ------------
# dailymail
# ------------
# not all arguments converted during string formatting : 32
# 'class' : 5
